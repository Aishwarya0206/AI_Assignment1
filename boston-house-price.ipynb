# %% [markdown]
# <a href="https://www.kaggle.com/izarafahein/boston-house-price?scriptVersionId=88835668" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Variables in order:
# * crim per capita crime rate by town
# * zn proportion of residential land zoned for lots over 25,000 sq.ft.
# * indus proportion of non-retail business acres per town
# * chas Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# * nox nitric oxides concentration (parts per 10 million)
# * rm average number of rooms per dwelling
# * age proportion of owner-occupied units built prior to 1940
# * dis weighted distances to five Boston employment centres
# * rad index of accessibility to radial highways
# * tax full-value property-tax rate per  10,000 's
# * ptratio pupil-teacher ratio by town
# * black 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# * lstat % lower status of the population
# * medv Median value of owner-occupied homes in $1000's

# %%
#Boston train set
boston_train = pd.read_csv("../input/boston-housepredict/boston_train.csv")
boston_train.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
boston_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       333 non-null    int64
#  1   crim     333 non-null    float64
#  2   zn       333 non-null    float64
#  3   indus    333 non-null    float64
#  4   chas     333 non-null    int64
#  5   nox      333 non-null    float64
#  6   rm       333 non-null    float64
#  7   age      333 non-null    float64
#  8   dis      333 non-null    float64
#  9   rad      333 non-null    int64
#  10  tax      333 non-null    int64
#  11  ptratio  333 non-null    float64
#  12  black    333 non-null    float64
#  13  lstat    333 non-null    float64
#  14  medv     333 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 39.1 KB

# %%
boston_train.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean   250.951952    3.360341   10.689189   11.293483    0.060060    0.557144
# std    147.859438    7.352272   22.674762    6.998123    0.237956    0.114955
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%    123.000000    0.078960    0.000000    5.130000    0.000000    0.453000
# 50%    244.000000    0.261690    0.000000    9.900000    0.000000    0.538000
# 75%    377.000000    3.678220   12.500000   18.100000    0.000000    0.631000
# max    506.000000   73.534100  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     6.265619   68.226426    3.709934    9.633634  409.279279   18.448048
# ...

# %% [markdown]
# ## Preprocessing and EDA

# %%
boston_train.isnull().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
boston_train.duplicated().sum()
# Out:
# 0

# %%
boston_train.nunique()
# Out:
# ID         333
# crim       332
# zn          25
# indus       68
# chas         2
# nox         77
# rm         308
# age        260
# dis        295
# rad          9
# tax         59
# ptratio     42
# black      237
# lstat      310
# medv       192
# dtype: int64

# %%
boston_train['chas'].unique()
# Out:
# array([0, 1])

# %%
boston_train['rad'].unique()
# Out:
# array([ 1,  2,  3,  5,  4,  8,  6,  7, 24])

# %%
boston_train['zn'].unique()
# Out:
# array([ 18. ,   0. ,  12.5,  75. ,  21. ,  90. ,  85. , 100. ,  25. ,
#         17.5,  80. ,  28. ,  45. ,  60. ,  95. ,  82.5,  30. ,  22. ,
#         20. ,  40. ,  55. ,  52.5,  34. ,  33. ,  35. ])

# %%
boston_train['ptratio'].unique()
# Out:
# array([15.3, 17.8, 18.7, 15.2, 21. , 19.2, 18.3, 17.9, 16.8, 21.1, 17.3,
#        15.1, 19.7, 18.6, 16.1, 18.9, 19. , 18.5, 18.2, 18. , 20.9, 19.1,
#        21.2, 14.7, 16.6, 15.6, 12.6, 17. , 16.4, 17.4, 13. , 17.6, 14.9,
#        13.6, 16. , 18.4, 19.6, 16.9, 20.2, 15.5, 15.9, 20.1])

# %%
#CRIM per capita crime rate by town decreases with decrease in MEDV Median value of owner-occupied homes in $1000's
sns.scatterplot(boston_train.medv, boston_train.crim)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='medv', ylabel='crim'>

# %%
plt.figure(dpi=100)
ax = sns.barplot(boston_train.zn, boston_train.medv)
xticks=ax.xaxis.get_major_ticks()
for i in range(len(xticks)):
  if i%2==1:
    xticks[i].set_visible(False)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(dpi=100)
ax = sns.scatterplot(boston_train.indus, boston_train.medv)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(dpi=100)
ax = sns.barplot(boston_train.chas, boston_train.medv)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(dpi=100)
sns.scatterplot(boston_train.nox, boston_train.medv)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='nox', ylabel='medv'>

# %%
plt.figure(dpi=100)
sns.scatterplot(boston_train.rm, boston_train.medv)
#As rm increases medv increases
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='rm', ylabel='medv'>

# %%
plt.figure(dpi=100)
sns.scatterplot(boston_train.dis, boston_train.medv)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='dis', ylabel='medv'>

# %%
plt.figure(dpi=100)
sns.barplot(boston_train.rad, boston_train.medv)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='rad', ylabel='medv'>

# %%
plt.figure(dpi=100)
sns.scatterplot(boston_train.ptratio, boston_train.medv)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='ptratio', ylabel='medv'>

# %%
plt.figure(dpi=100)
sns.scatterplot(boston_train.black, boston_train.medv)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='black', ylabel='medv'>

# %%
plt.figure(dpi=100)
sns.scatterplot(boston_train.lstat, boston_train.medv)
#Interpretation: lstat decreases with decrease in medv
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='lstat', ylabel='medv'>

# %%
dataset = [boston_train]
for data in dataset:
    data.loc[data['age'] <= 15, 'age'] = 0
    data.loc[(data['age'] > 15) & (data['age'] <= 30),'age'] = 1
    data.loc[(data['age'] > 30) & (data['age'] <= 45),'age'] = 2
    data.loc[(data['age'] > 45) & (data['age'] <= 60),'age'] = 3
    data.loc[data['age'] > 60, 'age'] = 4

# %%
plt.figure(dpi=100)
sns.barplot(boston_train.age, boston_train.medv)
#Interpretation: medv decreases as age decreases. Also, after 15 yrs the house medv increases
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='age', ylabel='medv'>

# %%
#Correlation between the data
boston_train.corr()
# Out:
#                ID      crim        zn     indus      chas       nox        rm  \
# ID       1.000000  0.456312 -0.155639  0.421978  0.007958  0.440185 -0.112790
# crim     0.456312  1.000000 -0.210913  0.422228 -0.041195  0.463001 -0.310180
# zn      -0.155639 -0.210913  1.000000 -0.518679 -0.024442 -0.501990  0.328197
# indus    0.421978  0.422228 -0.518679  1.000000  0.037496  0.750087 -0.440365
# chas     0.007958 -0.041195 -0.024442  0.037496  1.000000  0.080275  0.112251
# nox      0.440185  0.463001 -0.501990  0.750087  0.080275  1.000000 -0.338515
# rm      -0.112790 -0.310180  0.328197 -0.440365  0.112251 -0.338515  1.000000
# age      0.215639  0.277936 -0.544829  0.494765  0.070837  0.611195 -0.191553
# dis     -0.356461 -0.397067  0.637142 -0.702327 -0.081834 -0.769364  0.269191
# rad      0.707526  0.666636 -0.303663  0.569779  0.007714  0.612180 -0.272783
# tax      0.686246  0.617081 -0.311180  0.708313 -0.021826  0.670722 -0.356987
# ...

# %%
#Heatmap to view correlation
plt.figure(dpi=150)
sns.heatmap(boston_train.corr())
# Out:
# <AxesSubplot:>

# %%
#Negative correlation pairplot
sns.pairplot(boston_train, vars=['crim','indus','nox','age','rad','tax','ptratio','lstat','medv'])

# %%
#Positive correlation pairplot
sns.pairplot(boston_train, vars=['zn','chas','rm','dis','black','medv'])

# %%
X = boston_train.iloc[:,1:-1].values
Y = boston_train.iloc[:,-1].values

# %%
print("Independent Variables Shape for Train  : ", X.shape)
print("Dependent Variables Shape for Train    : ", Y.shape)
# Out:
# Independent Variables Shape for Train  :  (333, 13)
# Dependent Variables Shape for Train    :  (333,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 5)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-4.45478571e-02,  3.50571733e-02,  1.05897673e-01,  5.40352295e+00,
#        -1.86294484e+01,  3.71281966e+00, -6.53448661e-01, -1.66546217e+00,
#         2.81602863e-01, -1.06274628e-02, -8.43497145e-01,  1.03225417e-02,
#        -6.59003910e-01])

# %%
reg.intercept_
# Out:
# 38.17887201861859

# %%
print('Score on training data : ',reg.score(x_train, y_train))
print('Score on testing data  : ',reg.score(x_test, y_test))
# Out:
# Score on training data :  0.7367375318847509
# Score on testing data  :  0.6892559403958157

# %%
pred = reg.predict(x_train)

# %%
plt.plot(Y,'o')
plt.plot(reg.predict(x_train))
plt.plot(reg.predict(x_test))

# %%
from sklearn import metrics
print("Mean Absolute Error      :",metrics.mean_absolute_error(y_train, pred))
print("Mean Squared Error       :",metrics.mean_squared_error(y_train, pred))
print("Root Mean Squared Error  :",metrics.mean_squared_error(y_train, pred, squared=False))
print("Explained Variance       :",metrics.explained_variance_score(y_train, pred))
print("Max Error                :",metrics.max_error(y_train, pred))
print("MedAE                    :",metrics.median_absolute_error(y_train, pred))
print("R2 score                 :",metrics.r2_score(y_train, pred))
# Out:
# Mean Absolute Error      : 3.345309787335875
# Mean Squared Error       : 22.574085127367926
# Root Mean Squared Error  : 4.751219330589562
# Explained Variance       : 0.7367375318847509
# Max Error                : 23.888172240066034
# MedAE                    : 2.5709586958916297
# R2 score                 : 0.7367375318847509

# %% [markdown]
# ## Now let's assume RM and LSTAT are two good features of Boston house price, to visualize the graph of multiple regression.

# %%
boston_train.columns
# Out:
# Index(['ID', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
#        'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
X_sample = boston_train[['rm','lstat']].values
Y_sample = boston_train[['medv']].values

# %%
X_sample.shape
# Out:
# (333, 2)

# %%
Y_sample.shape
# Out:
# (333, 1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(X_sample, Y_sample, test_size = 0.2, random_state = 5)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([[ 4.79775232, -0.71142608]])

# %%
reg.intercept_
# Out:
# array([1.5028343])

# %%
r2 = reg.score(x_train, y_train)

# %%
print('Score on training sample data : ',reg.score(x_train, y_train))
print('Score on testing sample data  : ',reg.score(x_test, y_test))
# Out:
# Score on training sample data :  0.6301257015626027
# Score on testing sample data  :  0.6407306934066372

# %%
pred = reg.predict(x_train)

# %%
rm_range = np.linspace(3, 9, 30)  # range of rm
lstat_range = np.linspace(1, 38, 30)  # range of lstat
rm_range, lstat_range = np.meshgrid(rm_range, lstat_range)
model_viz = np.array([rm_range.flatten(), lstat_range.flatten()]).T

# Predict using model built on previous step
# ols = linear_model.LinearRegression()
# model = ols.fit(X, Y)
predicted = reg.predict(model_viz)

# Evaluate model by using it's R^2 score 
r2 = reg.score(X_sample, Y_sample)

# Plot model visualization
plt.style.use('fivethirtyeight')

fig = plt.figure(figsize=(12, 4))

ax1 = fig.add_subplot(131, projection='3d')
ax2 = fig.add_subplot(132, projection='3d')
ax3 = fig.add_subplot(133, projection='3d')

axes = [ax1, ax2, ax3]

for ax in axes:
    ax.plot(boston_train['rm'], boston_train['lstat'], boston_train['medv'], color='k', zorder=15, linestyle='none', marker='o', alpha=0.5)
    ax.scatter(rm_range.flatten(), lstat_range.flatten(), predicted, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
    ax.set_xlabel('rm', fontsize=12)
    ax.set_ylabel('lstat', fontsize=12)
    ax.set_zlabel('medv', fontsize=12)
    ax.locator_params(nbins=4, axis="boston_train['rm']")
    ax.locator_params(nbins=5, axis="boston_train['rm']")

ax1.view_init(elev=25, azim=-60)
ax2.view_init(elev=15, azim=15)
ax3.view_init(elev=25, azim=60)

fig.suptitle('Multi-Linear Regression Model Visualization ($R^2 = %.2f$)' % r2, fontsize=15, color='k')

fig.tight_layout()
